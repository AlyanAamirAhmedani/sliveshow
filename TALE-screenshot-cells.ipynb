# %% [markdown]
# # TALE 2026 — screenshot cells
#
# **Before capturing** (needs sliveshow **0.1.8**):
#
# 1. Theme: *Settings → Theme → JupyterLab Light* (dark dies on paper).
# 2. Browser zoom **125–150%** so fonts survive 9 cm print width.
# 3. **Figure 1 (triptych, 19 cm)** — use the *Gauss sum* cell below: capture (a) the cell in **edit mode** (double-click; the source is short on purpose), (b) the **notebook view** mid-animation, (c) the **slideshow** mid-animation (Sliveshow → Start from current cell).
# 4. **Figure 2 (film-strip, 9 cm)** — use the *binary search* cell: it is wide and short, perfect for 3 stacked frames. Screen-record it (Cmd+Shift+5 → Record), scrub to 3 telling moments (mid on 19 → left half faded, pointer moved → found green), export frames.
# 5. Crop tight, no browser chrome; capture in fullscreen slideshow where possible.
# 6. Test: print at target width — every label must be readable at arm's length.

# %% [markdown]
# <div data-animate>
# <h2>Why <code>sum(range(n+1))</code> equals <code>n*(n+1)//2</code></h2>
#
# $$\class{lhs}{\sum_{k=1}^{n} k} = \class{rhs}{\frac{n(n+1)}{2}}$$
#
# <!--
# {
#   "setup": [
#     { "element": ".lhs", "modifier": "attr", "parameters": [{ "fill": "#212529" }] },
#     { "element": ".rhs", "modifier": "attr", "parameters": [{ "fill": "#212529" }] }
#   ],
#   "animation": [
#     { "element": ".lhs", "modifier": "attr", "parameters": [{ "fill": "#1c7ed6" }], "duration": 600 },
#     { "element": ".lhs", "modifier": "attr", "parameters": [{ "fill": "#212529" }], "duration": 600 },
#     { "element": ".rhs", "modifier": "attr", "parameters": [{ "fill": "#e8590c" }], "duration": 600 },
#     { "element": ".rhs", "modifier": "attr", "parameters": [{ "fill": "#212529" }], "duration": 600 }
#   ],
#   "loop": true
# }
# -->
# </div>

# %% [markdown]
# <div data-animate>
# <h2>Binary search, step by step</h2>
# <svg xmlns="http://www.w3.org/2000/svg" width="760" height="170" font-family="Helvetica, Arial, sans-serif">
#   <text x="20" y="24" font-size="16" fill="#495057" font-family="Menlo, Consolas, monospace">binary_search(arr, target=31)</text>
#   <text id="mid" x="325" y="52" text-anchor="middle" font-size="15" font-weight="bold" fill="#e8590c" opacity="0">&#9660; mid</text>
#   <g id="g0"><rect x="20" y="60" width="70" height="50" rx="8" fill="#339af0"/><text x="55" y="92" text-anchor="middle" font-size="20" font-weight="bold" fill="white">3</text><text x="55" y="130" text-anchor="middle" font-size="12" fill="#868e96">0</text></g>
#   <g id="g1"><rect x="110" y="60" width="70" height="50" rx="8" fill="#339af0"/><text x="145" y="92" text-anchor="middle" font-size="20" font-weight="bold" fill="white">7</text><text x="145" y="130" text-anchor="middle" font-size="12" fill="#868e96">1</text></g>
#   <g id="g2"><rect x="200" y="60" width="70" height="50" rx="8" fill="#339af0"/><text x="235" y="92" text-anchor="middle" font-size="20" font-weight="bold" fill="white">12</text><text x="235" y="130" text-anchor="middle" font-size="12" fill="#868e96">2</text></g>
#   <g id="g3"><rect x="290" y="60" width="70" height="50" rx="8" fill="#339af0"/><text x="325" y="92" text-anchor="middle" font-size="20" font-weight="bold" fill="white">19</text><text x="325" y="130" text-anchor="middle" font-size="12" fill="#868e96">3</text></g>
#   <g id="g4"><rect x="380" y="60" width="70" height="50" rx="8" fill="#339af0"/><text x="415" y="92" text-anchor="middle" font-size="20" font-weight="bold" fill="white">25</text><text x="415" y="130" text-anchor="middle" font-size="12" fill="#868e96">4</text></g>
#   <g id="g5"><rect x="470" y="60" width="70" height="50" rx="8" fill="#339af0"/><text x="505" y="92" text-anchor="middle" font-size="20" font-weight="bold" fill="white">31</text><text x="505" y="130" text-anchor="middle" font-size="12" fill="#868e96">5</text></g>
#   <g id="g6"><rect x="560" y="60" width="70" height="50" rx="8" fill="#339af0"/><text x="595" y="92" text-anchor="middle" font-size="20" font-weight="bold" fill="white">40</text><text x="595" y="130" text-anchor="middle" font-size="12" fill="#868e96">6</text></g>
#   <g id="g7"><rect x="650" y="60" width="70" height="50" rx="8" fill="#339af0"/><text x="685" y="92" text-anchor="middle" font-size="20" font-weight="bold" fill="white">52</text><text x="685" y="130" text-anchor="middle" font-size="12" fill="#868e96">7</text></g>
#   <text id="found" x="505" y="155" text-anchor="middle" font-size="15" font-weight="bold" fill="#2f9e44" opacity="0">found!</text>
# </svg>
# <!--
# {
#   "animation": [
#     { "element": "#mid", "modifier": "opacity", "parameters": [1], "duration": 500 },
#     { "element": "#g3 rect", "modifier": "attr", "parameters": [{ "fill": "#e8590c" }], "duration": 500 },
#     { "element": "#g3 rect", "modifier": "attr", "parameters": [{ "fill": "#339af0" }], "duration": 300 },
#     { "element": "#g0,#g1,#g2,#g3", "modifier": "opacity", "parameters": [0.25], "duration": 700 },
#     { "element": "#mid", "modifier": "attr", "parameters": [{ "x": 505 }], "duration": 700 },
#     { "element": "#g5 rect", "modifier": "attr", "parameters": [{ "fill": "#e8590c" }], "duration": 500 },
#     { "element": "#g5 rect", "modifier": "attr", "parameters": [{ "fill": "#2f9e44" }], "duration": 500 },
#     { "element": "#found", "modifier": "opacity", "parameters": [1], "duration": 400 }
#   ],
#   "loop": true
# }
# -->
# </div>

# %% [markdown]
# :::{svg-animate} Circle
# <svg xmlns='http://www.w3.org/2000/svg' width='300' height='200'>
#   <circle id='c1' cx='80' cy='100' r='40' fill='#1c7ed6'/>
# </svg>
# <!--
# { "animation": [ { "element": "#c1", "modifier": "attr", "parameters": [{ "cx": 220 }], "duration": 1000 } ], "loop": true }
# -->
# :::
